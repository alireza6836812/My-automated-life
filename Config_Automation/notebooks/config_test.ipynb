# %%
import urllib.parse
import base64
import json
import socket
import time
import pandas as pd

# ============================================================
# Load previously generated VMESS configuration dataset
# ============================================================

vless_df = pd.read_excel(
    '/home/alireza/github/My-automated-life/Config_Automation/data/2)Scrapped_VMESS_Configs_json.xlsx'
)

# ============================================================
# Proxy Link Parsing Utilities
# ============================================================

def extract_host_port(proxy_link):
    """
    Extract target host and port from VLESS or VMESS proxy links.

    Supports:
    - vless://user@host:port?...
    - vmess://<base64-json>

    Returns:
        (host, port) as (str, int)
        (None, None) if parsing fails
    """
    if not isinstance(proxy_link, str):
        return None, None

    proxy_link = proxy_link.strip()

    # ----------------------------
    # VLESS parsing
    # ----------------------------
    if proxy_link.startswith("vless://"):
        try:
            parsed = urllib.parse.urlparse(proxy_link)

            # Expect userinfo before '@'
            if "@" not in parsed.netloc:
                return None, None

            netloc = parsed.netloc.split("@", 1)[1]

            if ":" not in netloc:
                return None, None

            host, port = netloc.rsplit(":", 1)
            return host, int(port)

        except Exception:
            return None, None

    # ----------------------------
    # VMESS parsing
    # ----------------------------
    elif proxy_link.startswith("vmess://"):
        try:
            # Strip scheme
            base64_config = proxy_link[8:]

            # Fix Base64 padding
            padding = 4 - len(base64_config) % 4
            if padding != 4:
                base64_config += "=" * padding

            # Decode Base64 → JSON
            json_config = base64.urlsafe_b64decode(base64_config).decode('utf-8')
            vmess_data = json.loads(json_config)

            # Extract address and port
            address = vmess_data.get("add", "")
            port = vmess_data.get("port", "")

            if not address or not port:
                return None, None

            return address, int(port)

        except Exception:
            return None, None

    return None, None

# ============================================================
# TCP Ping Functions
# ============================================================

def tcp_ping(host, port, timeout=2):
    """
    Perform a single TCP connection attempt and measure latency.

    Returns:
        latency in milliseconds
        None if unreachable
    """
    try:
        start = time.time()
        with socket.create_connection((host, port), timeout=timeout):
            return (time.time() - start) * 1000
    except Exception:
        return None

def batch_tcp_ping(proxy_links, timeout=2, max_workers=10):
    """
    Perform TCP ping on a list of proxy links.

    NOTE:
    Threading is imported but not used.
    Function currently runs sequentially.
    """
    import concurrent.futures

    results = []

    for link in proxy_links:
        host, port = extract_host_port(link)
        if host is not None:
            latency = tcp_ping(host, port, timeout)
            results.append(latency)
        else:
            results.append(None)

    return results

def enhanced_tcp_ping(host, port, timeout=3, retries=2):
    """
    TCP ping with retries and granular error handling.

    Retries connection attempts to handle transient network failures.
    """
    for attempt in range(retries):
        try:
            start = time.time()
            with socket.create_connection((host, port), timeout=timeout):
                return (time.time() - start) * 1000

        except socket.timeout:
            continue
        except ConnectionRefusedError:
            return None
        except socket.gaierror:
            return None
        except Exception:
            continue

    return None

# ============================================================
# Main Execution Loop
# ============================================================

latencies = []
successful_count = 0
failed_count = 0

for link in vless_df["links"]:
    host, port = extract_host_port(link)

    if host is not None and port is not None:
        print(f"Testing {host}:{port}...", end=" ")

        latency = enhanced_tcp_ping(host, port)

        if latency is not None:
            print(f"✓ {latency:.2f} ms")
            successful_count += 1
        else:
            print("✗ Failed")
            failed_count += 1

        latencies.append(latency)

    else:
        print(f"Could not parse: {link}")
        latencies.append(None)
        failed_count += 1

print(f"\nSummary: {successful_count} successful, {failed_count} failed")

# ============================================================
# Store and Rank Results
# ============================================================

# Attach latency results to DataFrame
vless_df["tcp_latency_ms"] = latencies

# Sort by fastest reachable proxies
vless_df = vless_df.sort_values(
    "tcp_latency_ms",
    na_position='last'
).reset_index(drop=True)

# Remove unreachable proxies
vless_df = vless_df.dropna(subset=['tcp_latency_ms'])

vless_df
# Out:
# Testing 95.216.183.113:42152... ✓ 146.67 ms
# Testing tr1-smart.adelping.com:80... ✓ 353.36 ms
# Testing 140.248.137.99:80... ✓ 106.58 ms
# Testing Cpannel.iranucshop.ir:2085... ✓ 1436.09 ms
# Testing 157.173.206.47:57449... ✗ Failed
# Testing servers.xvon.in:2087... ✗ Failed
# Testing 62.60.245.128:24448... ✗ Failed
# Testing 172.233.229.91:14102... ✓ 409.10 ms
# Testing 213.176.121.114:443... ✓ 59.41 ms
# Testing 213.176.121.158:443... ✓ 42.64 ms
# Testing 2.188.212.39:8080... ✓ 37.26 ms
# Testing nl.pingooo.org:2053... ✓ 226.53 ms
# Testing us.pingooo.org:80... ✓ 255.48 ms
# Testing 57.129.28.216:443... ✓ 162.17 ms
# Testing Cpannel.iranucshop.ir:2085... ✗ Failed
# Testing 47.250.45.234:43063... ✓ 351.35 ms
# Testing 91.134.8.101:443... ✓ 133.94 ms
# Testing dll.avaaaal.ir:8443... ✓ 6313.73 ms
# Testing digitalocean.com:8080... ✗ Failed
# Testing 172.67.204.84:8080... ✓ 353.98 ms
# Testing 85.17.192.110:16623... ✗ Failed
# Testing daily.pouya2.ir:6024... ✗ Failed
# Testing 15.235.50.172:443... ✓ 258.34 ms
# Testing 165.140.216.141:443... ✓ 261.95 ms
# Testing 172.234.132.232:10001... ✓ 395.65 ms
# Testing n1761214919.mv7wh.tech:443... ✓ 809.22 ms
# Testing 45.32.45.45:14760... ✗ Failed
# Testing 43.162.114.137:59674... ✗ Failed
# Testing azad4.deadlybook.lol:39306... ✗ Failed
# Testing 103.127.218.91:54693... ✗ Failed
# Testing 217.217.255.99:8443... ✗ Failed
# Testing 47.243.39.173:20522... ✗ Failed
# Testing 91.206.171.169:8080... ✓ 48.31 ms
# Testing 154.64.243.19:38533... ✗ Failed
# Testing 3h-kazakhstan1.09vpn.com:80... ✓ 5312.94 ms
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 150.230.43.106:54829... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 95.216.183.113:42152... ✓ 195.20 ms
# Testing 47.251.91.241:42899... ✓ 280.38 ms
# Testing 8.218.140.27:32876... ✗ Failed
# Testing 8.218.175.64:9754... ✗ Failed
# Testing chatgpt.com:443... ✓ 236.66 ms
# Testing 176.9.178.52:2052... ✗ Failed
# Testing 47.243.231.14:56304... ✗ Failed
# Testing 8.217.209.82:55764... ✗ Failed
# Testing 47.86.85.95:26006... ✗ Failed
# Testing 47.238.78.223:17723... ✗ Failed
# Testing 47.250.45.234:43063... ✓ 314.71 ms
# Testing 8.211.164.215:20522... ✗ Failed
# Testing 38.34.24.196:20522... ✗ Failed
# Testing 47.243.168.211:24680... ✗ Failed
# Testing 8.211.164.215:20522... ✗ Failed
# Testing 8.217.92.110:20522... ✗ Failed
# Testing 194.76.18.199:443... ✓ 114.77 ms
# Testing 156.233.232.177:44329... ✗ Failed
# Testing 198.62.62.199:443... ✓ 190.07 ms
# Testing 156.233.232.177:24004... ✓ 509.59 ms
# Testing vc.fly.dev:443... ✓ 10434.60 ms
# Testing 172.111.146.64:80... ✗ Failed
# Testing 8.210.52.211:20522... ✗ Failed
# Testing 172.67.197.47:443... ✓ 207.73 ms
# Testing 47.243.95.187:443... ✓ 334.03 ms
# Testing 5.75.192.248:30050... ✗ Failed
# Testing 94.232.247.165:45653... ✓ 34.15 ms
# Testing 104.21.69.44:8080... ✓ 118.85 ms
# Testing 45.128.54.84:37313... ✗ Failed
# Testing s1.connect.bloroxy.net:1117... ✓ 3268.32 ms
# Testing 47.236.64.216:8080... ✗ Failed
# Testing digitalocean.com:8080... ✓ 705.36 ms
# Testing 8.6.112.0:2083... ✓ 28.15 ms
# Testing 37.152.175.93:2010... ✓ 39.54 ms
# Testing 89.44.242.242:7001... ✓ 36.04 ms
# Testing 89.44.242.255:2010... ✓ 36.73 ms
# Testing 89.44.242.255:2010... ✓ 29.34 ms
# Testing 89.44.242.255:2010... ✓ 72.41 ms
# Testing 89.44.242.255:2010... ✓ 36.99 ms
# Testing 89.44.242.247:2040... ✓ 60.37 ms
# Testing 147.135.211.61:8080... ✗ Failed
# Testing de.zarasite.ir:6533... ✗ Failed
# Testing n1753598445.74qxv.top:443... ✓ 1193.66 ms
# Testing se-1-tun.claudify.cloud:8080... ✗ Failed
# Testing Cpannel.iranucshop.ir:2085... ✗ Failed
# Testing 20.193.153.19:15834... ✓ 121.86 ms
# Testing servers.xvon.in:2087... ✓ 20100.02 ms
# Testing digitalocean.com:8080... ✓ 10127.52 ms
# Testing tr1-smart.adelping.com:80... ✗ Failed
# Testing ::ffff:ac40:9bd1:443... ✓ 66.60 ms
# Testing seoul03.zgjok.com:443... ✗ Failed
# Testing vip3.kaixincloud.top:2083... ✗ Failed
# Testing vip1.kaixincloud.top:443... ✗ Failed
# Testing s2.fastly4wards.com:2088... ✓ 5036.00 ms
# Testing s1.fastly4wards.com:2087... ✗ Failed
# Testing s3.fastly4wards.com:2089... ✗ Failed
# Testing s3.fastly4wards.com:2089... ✓ 259.48 ms
# Testing 172.64.149.182:8080... ✓ 50.88 ms
# Testing chatgpt.com:8080... ✗ Failed
# Testing ::ffff:ac40:9bd1:443... ✓ 124.85 ms
# Testing farzad.vipgsmteam.info:33953... ✗ Failed
# Testing 81.12.33.161:1016... ✓ 72.50 ms
# Testing callmevpn8.callmeshop.fun:12128... ✓ 15422.57 ms
# Testing 104.20.14.250:2053... ✓ 112.48 ms
# Testing 94.131.108.36:443... ✓ 32.88 ms
# Testing 94.131.108.36:443... ✓ 29.31 ms
# Testing 91.107.185.224:443... ✗ Failed
# Testing 91.107.185.224:8080... ✗ Failed
# Testing 185.146.173.25:80... ✓ 139.28 ms
# Testing 140.248.128.22:80... ✓ 33.96 ms
# Testing radhan.configraybot.sbs:11559... ✗ Failed
# Testing cpanel.navar1.ir:100... ✗ Failed
# Testing 155.254.35.160:29912... ✗ Failed
# Testing lammaland.org:443... ✗ Failed
# Testing 146.59.118.250:443... ✓ 40.51 ms
# Testing serkat.org:443... ✗ Failed
# Testing 146.59.118.250:443... ✓ 45.30 ms
# Testing fapeng.org:443... ✗ Failed
# Testing 91.99.157.193:2052... ✗ Failed
# Testing pro2.prgame.xyz:59442... ✗ Failed
# Testing 142.132.227.65:48247... ✗ Failed
# Testing 142.132.227.65:48247... ✗ Failed
# Testing speedtest.net:80... ✓ 13271.26 ms
# Testing 95.38.140.102:45090... ✗ Failed
# Testing 89.44.112.34:2535... ✗ Failed
# Testing prod2-fh-cloud-hybrid01-vmt01.cyberscaler.com:37333... ✗ Failed
# Testing vip.ertebatgoostar.org:2083... ✗ Failed
# Testing m29.vaxon1.click:80... ✗ Failed
# Testing m30.vaxon1.click:80... ✓ 160.59 ms
# Testing 81.12.33.193:8080... ✗ Failed
# Testing irbalaz.parhamsanji.ir:2050... ✗ Failed
# Testing 89.44.243.231:51891... ✗ Failed
# Testing fast.v2sub.online:80... ✗ Failed
# Testing 85.198.23.63:52262... ✗ Failed
# Testing 195.182.38.168:17836... ✗ Failed
# Testing 212.23.214.22:20001... ✗ Failed
# Testing e1.ilysm.space:60... ✗ Failed
# Testing v2r.datax.click:1102... ✗ Failed
# Testing 5.75.207.190:8443... ✗ Failed
# Testing 93.127.180.122:8880... ✗ Failed
# Testing 157.180.124.81:29301... ✗ Failed
# Testing kapelleng.com:443... ✗ Failed
# Testing blog.tele-shop-too.studio:33157... ✗ Failed
# Testing kapelleng.com:443... ✗ Failed
# Testing 57.129.132.223:80... ✗ Failed
# Testing 147.135.211.61:8080... ✗ Failed
# Testing servers.xvon.in:2087... ✓ 304.74 ms
# Testing servers.xvon.in:2087... ✓ 218.48 ms
# Testing turk1.net.net:80... ✓ 494.39 ms
# Testing 188.114.98.0:8080... ✗ Failed
# Testing 172.233.229.91:14102... ✓ 292.88 ms
# Testing turk1.net.net:80... ✓ 3334.09 ms
# Testing https://github.com/ALIILAPRO/v2rayNG-Config:433... ✗ Failed
# Testing 103.127.218.91:54693... ✗ Failed
# Testing 94.156.181.190:46103... ✓ 116.35 ms
# Testing 217.217.255.99:8443... ✗ Failed
# Testing 157.173.206.47:57449... ✗ Failed
# Testing 94.232.247.165:45653... ✓ 28.02 ms
# Testing yichueng.org:443... ✗ Failed
# Testing 15.235.83.228:443... ✓ 33.29 ms
# Testing serkat.org:443... ✗ Failed
# Testing 8.210.140.23:54809... ✗ Failed
# Testing 47.83.18.10:36968... ✗ Failed
# Testing 161.248.30.3:20086... ✗ Failed
# Testing fapeng.org:443... ✗ Failed
# Testing 547.rtxconfigz.shop:8080... ✗ Failed
# Testing t1.620720.xyz:8443... ✗ Failed
# Testing 15.235.41.200:80... ✗ Failed
# Testing 38.92.10.226:45979... ✗ Failed
# Testing 51.79.102.253:80... ✗ Failed
# Testing v2ray.codefyinc.com:443... ✗ Failed
# Testing 198.23.174.168:20086... ✗ Failed
# Testing cg1c07.waimaojd.com:443... ✗ Failed
# Testing support.zoom.us:8080... ✓ 5521.30 ms
# Testing 209.126.84.189:443... ✓ 28.94 ms
# Testing sy4.620720.xyz:443... ✗ Failed
# Testing hgtrojan.zabc.net:2083... ✓ 634.40 ms
# Testing cg1c01.waimaojd.com:443... ✗ Failed
# Testing cg1c04.waimaojd.com:443... ✓ 5251.28 ms
# Testing cg1c14.waimaojd.com:443... ✗ Failed
# Testing digitalocean.com:8080... ✓ 8513.22 ms
# Testing tgju.org:8080... ✓ 484.33 ms
# Testing turk1.net.net:80... ✓ 5202.55 ms
# Testing 188.114.98.0:8080... ✓ 204.29 ms
# Testing bbnj.wc9.ccwu.cc:80... ✗ Failed
# Testing 82.21.80.224:17310... ✓ 406.94 ms
# Testing 172.64.149.182:8080... ✓ 47.35 ms
# Testing nextmi.hajmyab.ir:2053... ✓ 10039.31 ms
# Testing v10.hdacd.com:30807... ✓ 801.67 ms
# Testing 2001:bc8:32d7:302::15:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::17:44579... ✗ Failed
# Testing v12.hdacd.com:30812... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing v12.hdacd.com:30812... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::11:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::14:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::11:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing bbnj.wc9.ccwu.cc:80... ✗ Failed
# Testing v30.hdacd.com:30830... ✗ Failed
# Testing yhj.tc1.ccwu.cc:80... ✗ Failed
# Testing nju.bb4.indevs.in:80... ✗ Failed
# Testing mmkio.wc5.ccwu.cc:80... ✗ Failed
# Testing mmko.tt0.ccwu.cc:80... ✗ Failed
# Testing nextmi.hajmyab.ir:2053... ✓ 729.03 ms
# Testing v30.hdacd.com:30830... ✗ Failed
# Testing 2001:bc8:32d7:302::10:44579... ✗ Failed
# Testing nmj.wc8.ccwu.cc:80... ✗ Failed
# Testing ert.859885.xyz:443... ✗ Failed
# Testing mmkio.tc6.ccwu.cc:80... ✗ Failed
# Testing bbbnmki.kk7.ccwu.cc:80... ✗ Failed
# Testing vc.fly.dev:443... ✓ 5172.66 ms
# Testing 82.198.246.97:180... ✗ Failed
# Testing 85.211.192.75:16616... ✓ 363.69 ms
# Testing bnmj.wc6.ccwu.cc:80... ✗ Failed
# Testing mkirt.818185.xyz:443... ✗ Failed
# Testing vg.333756.xyz:443... ✗ Failed
# Testing v10.hdacd.com:30807... ✓ 836.46 ms
# Testing 127.1.1.127:80... ✗ Failed
# Testing 161.248.30.3:20086... ✗ Failed
# Testing yichueng.org:443... ✗ Failed
# Testing 8.210.140.23:54809... ✗ Failed
# Testing turk1.net.net:80... ✓ 3588.97 ms
# Testing https://github.com/ALIILAPRO/v2rayNG-Config:433... ✗ Failed
# Testing tgju.org:8080... ✓ 482.76 ms
# Testing serkat.org:443... ✗ Failed
# Testing 104.24.169.183:8080... ✓ 147.97 ms
# Testing 157.173.206.47:57449... ✗ Failed
# Testing 104.21.69.44:8080... ✓ 140.25 ms
# Testing 47.83.18.10:36968... ✗ Failed
# Testing fapeng.org:443... ✗ Failed
# Testing 217.217.255.99:8443... ✗ Failed
# Testing 103.127.218.91:54693... ✗ Failed
# Testing 15.235.83.228:443... ✓ 41.79 ms
# Testing 94.232.247.165:45653... ✓ 35.37 ms
# Testing 57.129.28.63:443... ✓ 138.68 ms
# Testing 57.129.28.216:443... ✓ 234.13 ms
# Testing 57.129.25.22:443... ✓ 112.00 ms
# Testing 158.51.121.63:443... ✓ 28.92 ms
# Testing channel.dollardoon.com:15709... ✗ Failed
# Testing 43.199.24.247:3000... ✗ Failed
# Testing 152.67.8.205:80... ✗ Failed
# Testing 146.59.55.50:443... ✓ 166.03 ms
# Testing 15.235.50.172:443... ✗ Failed
# Testing 23.162.200.227:443... ✓ 215.69 ms
# Testing 38.99.82.193:443... ✗ Failed
# Testing 15.235.83.227:443... ✓ 28.70 ms
# Testing 15.204.234.200:41100... ✗ Failed
# Testing 57.129.25.20:443... ✓ 116.59 ms
# Testing 57.129.64.238:443... ✓ 166.29 ms
# Testing 154.90.49.57:58868... ✗ Failed
# Testing v10.heduian.link:30807... ✗ Failed
# Testing 202.79.161.188:443... ✗ Failed
# Testing 134.195.198.147:443... ✓ 201.01 ms
# Testing 51.79.86.182:42610... ✗ Failed
# Testing 94.136.185.230:10534... ✗ Failed
# Testing 57.129.25.22:443... ✓ 223.40 ms
# Testing 103.124.107.144:29800... ✗ Failed
# Testing 57.129.24.124:443... ✓ 122.87 ms
# Testing 57.129.25.25:443... ✓ 34.25 ms
# Testing 161.248.30.3:20086... ✗ Failed
# Testing 135.125.182.74:28213... ✗ Failed
# Testing 57.129.28.65:443... ✓ 45.36 ms
# Testing 82.29.132.9:20086... ✗ Failed
# Testing 46.250.243.56:50394... ✗ Failed
# Testing 15.204.11.190:15361... ✗ Failed
# Testing 57.129.24.125:443... ✓ 204.88 ms
# Testing 51.38.64.209:44023... ✗ Failed
# Testing 57.129.28.69:443... ✓ 44.62 ms
# Testing 15.235.83.228:443... ✗ Failed
# Testing vc.fly.dev:443... ✗ Failed
# Testing 103.61.139.137:20521... ✗ Failed
# Testing 5.75.192.248:26207... ✓ 122.19 ms
# Testing 5.75.192.248:30050... ✓ 107.19 ms
# Testing 95.216.183.113:42152... ✓ 141.03 ms
# Testing 77.42.77.66:40100... ✓ 35.93 ms
# Testing nl-cdn2.nigtgemshopnew.org:443... ✓ 282.65 ms
# Testing cdn.nightgemshop.com:443... ✗ Failed
# Testing cdn-nightgemshop.sep-vpn.site:443... ✓ 1035.29 ms
# Testing 95.216.183.113:42152... ✓ 204.44 ms
# Testing 95.216.183.113:42152... ✓ 204.61 ms
# Testing 104.19.55.79:2052... ✓ 204.20 ms
# Testing a1.perspolisgamebooster.ir:58223... ✗ Failed
# Testing 150.230.43.106:54829... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 8.6.112.0:2083... ✓ 100.96 ms
# Testing frankfurt02.zgjok.com:443... ✓ 1340.17 ms
# Testing frankfurt01.zgjok.com:443... ✓ 429.61 ms
# Testing 150.230.43.106:54829... ✗ Failed
# Testing 91.134.8.101:443... ✓ 202.34 ms
# Testing tgju.org:8080... ✓ 3492.88 ms
# Testing vc.fly.dev:443... ✓ 10117.80 ms
# Testing 95.216.183.113:42152... ✓ 128.61 ms
# Testing irnet.greenetplus.ir:110... ✓ 516.75 ms
# Testing 104.24.169.183:8080... ✓ 149.47 ms
# Testing 47.243.135.74:55185... ✓ 466.95 ms
# Testing 51.79.103.76:80... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 91.206.171.169:8080... ✓ 62.87 ms
# Testing daily.pouya2.ir:6024... ✓ 347.44 ms
# Testing digitalocean.com:8080... ✓ 5137.29 ms
# Testing dll.avaaaal.ir:8443... ✓ 5733.15 ms
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing 45.136.12.37:20521... ✗ Failed
# Testing 45.15.170.237:80... ✓ 206.20 ms
# Testing 45.15.185.17:80... ✓ 502.25 ms
# Testing 47.243.135.74:55185... ✓ 306.65 ms
# Testing 5.196.29.123:2082... ✓ 146.77 ms
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 51.79.103.76:80... ✗ Failed
# Testing 57.129.132.223:80... ✗ Failed
# Testing 57.129.28.216:443... ✓ 152.96 ms
# Testing 61.245.11.60:80... ✓ 410.35 ms
# Testing 62.60.245.128:24448... ✗ Failed
# Testing 62.60.245.128:24448... ✗ Failed
# Testing 79.137.203.29:8080... ✓ 118.77 ms
# Testing 79.137.203.29:8080... ✓ 142.68 ms
# Testing 8.210.79.212:55185... ✗ Failed
# Testing 8.217.13.74:31769... ✗ Failed
# Testing 8.6.112.0:2083... ✓ 29.58 ms
# Testing 81.12.33.180:2078... ✗ Failed
# Testing 81.12.33.180:2020... ✗ Failed
# Testing 81.12.33.180:2024... ✓ 72.05 ms
# Testing 81.12.33.180:8595... ✗ Failed
# Testing 8103.shomaparvazroyadetonnist-bypassishere.lat:8103... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 91.206.171.169:8080... ✓ 44.45 ms
# Testing 91.206.171.169:8080... ✓ 58.35 ms
# Testing 95.216.183.113:42152... ✓ 159.27 ms
# Testing 95.216.183.113:42152... ✓ 204.44 ms
# Testing 95.216.183.113:42152... ✗ Failed
# Testing 95.216.183.113:42152... ✓ 211.82 ms
# Testing 95.216.183.113:42152... ✗ Failed
# Testing 95.217.25.69:42152... ✓ 217.47 ms
# Testing 95.217.25.69:42152... ✓ 142.31 ms
# Testing 95.217.25.69:42152... ✓ 129.54 ms
# Testing 95.217.25.69:42152... ✓ 171.85 ms
# Testing ::ffff:ac40:9bd1:443... ✓ 154.38 ms
# Testing 102.177.189.101:443... ✗ Failed
# Testing 103.97.203.220:550... ✓ 37.29 ms
# Testing 104.16.18.108:2087... ✓ 152.93 ms
# Testing 104.21.69.44:8080... ✓ 187.12 ms
# Testing 104.21.69.44:8080... ✓ 169.15 ms
# Testing 104.21.69.44:8080... ✓ 152.63 ms
# Testing 104.24.169.183:8080... ✓ 133.84 ms
# Testing 104.24.169.183:8080... ✓ 317.50 ms
# Testing 12812.shomaparvazroyadetonnist-bypassishere.lat:12812... ✗ Failed
# Testing 131.186.63.89:11655... ✓ 65.58 ms
# Testing 141.101.122.122:8080... ✓ 175.44 ms
# Testing 141.101.123.123:2086... ✓ 104.92 ms
# Testing 141.94.155.229:443... ✓ 117.56 ms
# Testing 147.135.211.61:8080... ✗ Failed
# Testing 148.113.176.192:443... ✓ 202.58 ms
# Testing 149.88.95.217:40741... ✓ 312.24 ms
# Testing 15.235.85.156:443... ✓ 481.99 ms
# Testing 162.159.152.4:443... ✓ 211.76 ms
# Testing 162.159.5.245:8443... ✓ 201.67 ms
# Testing 172.234.132.232:10001... ✓ 198.94 ms
# Testing 172.64.149.182:8080... ✓ 53.53 ms
# Testing 172.64.149.182:8080... ✓ 57.83 ms
# Testing 172.64.149.182:8080... ✓ 78.66 ms
# Testing 172.67.204.84:8080... ✓ 128.78 ms
# Testing 173.249.209.146:20086... ✗ Failed
# Testing 18.168.124.58:80... ✗ Failed
# Testing 18.168.124.58:80... ✗ Failed
# Testing 188.114.98.0:8080... ✗ Failed
# Testing 193.151.134.178:17356... ✗ Failed
# Testing 193.151.134.178:17356... ✗ Failed
# Testing 20.193.153.19:15834... ✓ 135.55 ms
# Testing 20.193.153.19:15834... ✓ 113.15 ms
# Testing 20.193.153.19:15834... ✓ 116.35 ms
# Testing 209.126.84.189:443... ✓ 31.64 ms
# Testing 209.126.84.189:443... ✓ 53.04 ms
# Testing 217.217.255.99:8443... ✗ Failed
# Testing 217.60.247.108:8080... ✓ 59.01 ms
# Testing 217.60.247.108:8080... ✓ 38.06 ms
# Testing tgju.org:8080... ✓ 5612.55 ms
# Testing tgju.org:8080... ✓ 5098.26 ms
# Testing tehran-sms.xyz:443... ✗ Failed
# Testing tr1-smart.adelping.com:80... ✓ 350.59 ms
# Testing tr1-smart.adelping.com:80... ✗ Failed
# Testing tr1-smart.adelping.com:80... ✓ 377.03 ms
# Testing tr1-smart.adelping.com:80... ✓ 356.81 ms
# Testing tr1-smart.adelping.com:80... ✓ 5484.22 ms
# Testing tr1-smart.adelping.com:80... ✓ 225.87 ms
# Testing tr1-smart.adelping.com:80... ✓ 5061.46 ms
# Testing tr1-smart.adelping.com:80... ✓ 253.79 ms
# Testing tr1-smart.adelping.com:80... ✗ Failed
# Testing adelmeli.com:80... ✓ 367.77 ms
# Testing daily.pouya2.ir:6024... ✗ Failed
# Testing de2c.buzzon.shop:443... ✗ Failed
# Testing de2c.buzzon.shop:443... ✗ Failed
# Testing de2c.buzzon.shop:80... ✗ Failed
# Testing de2c.buzzon.shop:80... ✗ Failed
# Testing digitalocean.com:8080... ✓ 676.59 ms
# Testing digitalocean.com:8080... ✗ Failed
# Testing digitalocean.com:8080... ✗ Failed
# Testing e0349a52-sv8cg0-t7uinf-i8ie.hk3.p5pv.com:80... ✗ Failed
# Testing hb.seacloudmachinery.com:2086... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing id-lb.vhax.net:80... ✗ Failed
# Testing irpnl.janebx.ir:444... ✗ Failed
# Testing n1753598451.74qxv.top:443... ✓ 5692.39 ms
# Testing pl37.salar4040.com:44701... ✗ Failed
# Testing pq-Hungary1.09vpn.com:80... ✓ 455.90 ms
# Testing pq-Hungary1.09vpn.com:80... ✗ Failed
# Testing pq-Hungary1.09vpn.com:80... ✓ 379.51 ms
# Testing s1.connect.bloroxy.net:1074... ✓ 6358.76 ms
# Testing s2.abtinphone.com:57392... ✗ Failed
# Testing seoul03.zgjok.com:443... ✓ 20403.23 ms
# Testing 95.217.25.69:42152... ✗ Failed
# Testing chatgpt.com:443... ✓ 10098.45 ms
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 85.17.192.110:16623... ✗ Failed
# Testing homeyra.taz-min.com:33221... ✓ 5051.58 ms
# Testing homeyra.taz-min.com:33221... ✓ 486.06 ms
# Testing hk2.lrzdx.uk:443... ✓ 626.77 ms
# Testing xcf037.facai2024.com:443... ✓ 5325.24 ms
# Testing 5.161.156.196:443... ✗ Failed
# Testing 172.67.207.114:443... ✓ 136.80 ms
# Testing mute-math-d64e.0e503992ad7026.WOrKERs.deV:443... ✓ 3452.93 ms
# Testing 142.132.163.200:80... ✓ 128.82 ms
# Testing us-2.0rd.net:443... ✗ Failed
# Testing 168.119.174.229:443... ✓ 167.13 ms
# Testing 104.16.60.8:2086... ✓ 143.45 ms
# Testing 104.21.15.212:443... ✓ 231.42 ms
# Testing 77.v2ray1.xyz:443... ✗ Failed
# Testing 172.66.213.38:443... ✓ 144.72 ms
# Testing cold-dawn-9246.fly.dev:443... ✗ Failed
# Testing baawftvbh.76898102.xyz:2052... ✗ Failed
# Testing frarmbc.76898102.xyz:2052... ✗ Failed
# Testing frarmbc.76898102.xyz:2052... ✗ Failed
# Testing basblamd.76898102.xyz:2052... ✗ Failed
# Testing basblamd.76898102.xyz:2052... ✗ Failed
# Testing baxamdyfa.76898102.xyz:2052... ✗ Failed
# Testing baxamdyfa.76898102.xyz:2052... ✗ Failed
# Testing baxwabe.76898102.xyz:2052... ✗ Failed
# Testing baxwabe.76898102.xyz:2052... ✗ Failed
# Testing baxwarfrey.76898102.xyz:2052... ✗ Failed
# Testing baxwarfrey.76898102.xyz:2052... ✗ Failed
# Testing bxawdbwdtyhjsgd.76898102.xyz:2052... ✗ Failed
# Testing bxawdbwdtyhjsgd.76898102.xyz:2052... ✗ Failed
# Testing bawfewbwagr.76898102.xyz:2086... ✗ Failed
# Testing bawfewbwagr.76898102.xyz:2086... ✗ Failed
# Testing dearma.76898102.xyz:2052... ✗ Failed
# Testing dearma.76898102.xyz:2052... ✗ Failed
# Testing dearmb.76898102.xyz:2052... ✗ Failed
# Testing dearmb.76898102.xyz:2052... ✗ Failed
# Testing dubawtgfnewi.76898102.xyz:2052... ✗ Failed
# Testing msiawdfgz.76898102.xyz:11827... ✗ Failed
# Testing msiawdfgz.76898102.xyz:11827... ✗ Failed
# Testing usblog.114514782.xyz:2052... ✗ Failed
# Testing usblog.114514782.xyz:2052... ✗ Failed
# Testing aisugvdiu.114514782.xyz:2082... ✗ Failed
# Testing aisugvdiu.114514782.xyz:2082... ✗ Failed
# Testing greencloudkss.114514782.xyz:8880... ✗ Failed
# Testing greencloudkss.114514782.xyz:8880... ✗ Failed
# Testing apkwvctghw.114514782.xyz:2052... ✓ 972.31 ms
# Testing apkwvctghw.114514782.xyz:2052... ✓ 1246.72 ms
# Testing asbawufh.114514782.xyz:2052... ✗ Failed
# Testing asbawufh.114514782.xyz:2052... ✗ Failed
# Testing jpwadnca.114514782.xyz:2052... ✗ Failed
# Testing jpwadnca.114514782.xyz:2052... ✗ Failed
# Testing jpntgrwq.114514782.xyz:2052... ✗ Failed
# Testing jpntgrwq.114514782.xyz:2052... ✗ Failed
# Testing usshsaba.114514782.xyz:2095... ✗ Failed
# Testing usshsaba.114514782.xyz:2095... ✗ Failed
# Testing usshsbab.114514782.xyz:2052... ✗ Failed
# Testing usshsbab.114514782.xyz:2052... ✗ Failed
# Testing 95.211.58.55:16418... ✗ Failed
# Testing 35.156.177.79:55164... ✗ Failed
# Testing 51.77.158.169:2096... ✗ Failed
# Testing 80.92.204.210:14984... ✗ Failed
# Testing 168.119.167.204:443... ✗ Failed
# Testing 185.174.138.34:2082... ✗ Failed
# Testing scheretest01.sobhsepid.com:443... ✗ Failed
# Testing 51.77.215.62:40846... ✗ Failed
# Testing 45.85.119.48:2053... ✓ 138.95 ms
# Testing 45.85.118.88:443... ✓ 118.87 ms
# Testing 78.47.131.39:443... ✗ Failed
# Testing 91.107.171.113:443... ✓ 32.57 ms
# Testing 65.109.213.137:16834... ✓ 47.33 ms
# Testing 185.137.24.247:32264... ✗ Failed
# Testing 37.32.6.147:18579... ✗ Failed
# Testing v2ray.v2rayngorg.live:443... ✗ Failed
# Testing 152.67.161.155:17355... ✗ Failed
# Testing srpars1-5.mehyaz.shop:44739... ✗ Failed
# Testing 45.85.118.88:8443... ✓ 123.01 ms
# Testing 162.159.58.88:80... ✓ 134.79 ms
# Testing 192.3.150.233:8443... ✗ Failed
# Testing se-ls03.nb1.fr:64443... ✗ Failed
# Testing 91.107.195.173:443... ✗ Failed
# Testing 159.69.248.191:443... ✗ Failed
# Testing 168.138.68.36:14252... ✗ Failed
# Testing 185.242.87.161:55254... ✗ Failed
# Testing 91.107.190.249:443... ✗ Failed
# Testing 116.203.1.197:8443... ✗ Failed
# Testing sea21.nb1.fr:64443... ✗ Failed
# Testing vc-usa.181227.xyz:443... ✗ Failed
# Testing shecanmci.symodi.ml:8880... ✗ Failed
# Testing 95.216.183.164:8080... ✗ Failed
# Testing 91.107.235.169:59470... ✗ Failed
# Testing 8.218.150.29:31595... ✗ Failed
# Testing 45.85.118.83:2052... ✓ 110.84 ms
# Testing 45.85.119.48:2053... ✓ 208.26 ms
# Testing 78.47.186.183:443... ✓ 164.94 ms
# Testing 45.85.119.48:2053... ✓ 218.32 ms
# Testing 45.85.118.1:443... ✓ 204.06 ms
# Testing 57.129.132.223:80... ✗ Failed
# Testing pq-Hungary1.09vpn.com:80... ✓ 466.09 ms
# Testing 45.141.148.143:5059... ✓ 367.56 ms
# Testing n1761214907.74qxv.top:443... ✓ 5319.40 ms
# Testing 209.126.84.189:443... ✓ 55.17 ms
# Testing 47.251.91.241:42899... ✗ Failed
# Testing 45.89.52.207:39651... ✓ 68.62 ms
# Testing 51.79.103.76:80... ✗ Failed
# Testing 69.63.210.35:24943... ✓ 43.74 ms
# Testing 51.79.102.253:80... ✗ Failed
# Testing 8.210.79.212:55185... ✓ 473.65 ms
# Testing 85.17.192.110:16623... ✗ Failed
# Testing 89.31.120.192:443... ✗ Failed
# Testing 94.232.247.165:45653... ✓ 102.76 ms
# Testing 188.114.98.0:8080... ✓ 127.19 ms
# Testing 104.21.69.44:8080... ✗ Failed
# Testing 162.159.152.4:443... ✗ Failed
# Testing 152.70.92.69:80... ✗ Failed
# Testing 172.64.149.182:8080... ✓ 63.55 ms
# Testing 162.19.248.238:550... ✗ Failed
# Testing 172.67.204.84:8080... ✓ 282.14 ms
# Testing 172.233.229.91:14102... ✓ 201.96 ms
# Testing 192.227.249.227:27641... ✓ 233.27 ms
# Testing 20.193.153.19:15834... ✗ Failed
# Testing 217.60.247.108:8080... ✓ 39.02 ms
# Testing tgju.org:8080... ✗ Failed
# Testing tr1-smart.adelping.com:80... ✗ Failed
# Testing v2ray.codefyinc.com:443... ✗ Failed
# Testing frankfurt02.zgjok.com:443... ✗ Failed
# Testing digitalocean.com:8080... ✓ 5142.09 ms
# Testing 5.83.150.108:31094... ✓ 37.36 ms
# Testing 5.83.150.108:35418... ✗ Failed
# Testing 5.83.150.108:30782... ✓ 84.04 ms
# Testing 5.83.150.108:10114... ✓ 57.02 ms
# Testing 5.83.150.108:49727... ✗ Failed
# Testing 5.83.150.108:51263... ✓ 41.71 ms
# Testing 5.83.150.108:28712... ✓ 26.61 ms
# Testing 5.83.150.108:45489... ✓ 59.69 ms
# Testing 5.83.150.108:19670... ✓ 35.04 ms
# Testing 5.83.150.108:37075... ✓ 83.42 ms
# Testing 5.83.150.108:31955... ✓ 62.17 ms
# Testing 5.83.150.108:40508... ✓ 25.81 ms
# Testing 5.83.150.108:65147... ✓ 26.06 ms
# Testing 5.83.150.108:40085... ✓ 39.91 ms
# Testing 5.83.150.108:45287... ✓ 44.68 ms
# Testing 5.83.150.108:36445... ✓ 28.62 ms
# Testing 5.83.150.108:45095... ✓ 29.65 ms
# Testing 5.83.150.108:40966... ✓ 35.26 ms
# Testing 5.83.150.108:40487... ✓ 60.57 ms
# Testing 5.83.150.108:24020... ✗ Failed
# Testing 5.83.150.108:10266... ✓ 41.91 ms
# Testing 94.156.181.190:11756... ✓ 204.07 ms
# Testing 94.156.181.190:23991... ✓ 121.32 ms
# Testing 94.156.181.190:58090... ✓ 142.40 ms
# Testing 94.156.181.190:15323... ✓ 146.81 ms
# Testing 94.156.181.190:21614... ✓ 169.66 ms
# Testing 94.156.181.190:40173... ✓ 1198.04 ms
# Testing 94.156.181.190:22857... ✓ 145.09 ms
# Testing 94.156.181.190:54102... ✓ 135.49 ms
# Testing 94.156.181.190:44977... ✓ 142.08 ms
# Testing 94.156.181.190:22484... ✓ 122.52 ms
# Testing 94.156.181.190:29548... ✓ 199.67 ms
# Testing 94.156.181.190:27469... ✓ 172.07 ms
# Testing 94.156.181.190:51408... ✓ 163.63 ms
# Testing 94.156.181.190:58791... ✓ 132.26 ms
# Testing 94.156.181.190:38605... ✓ 121.73 ms
# Testing 94.156.181.190:37123... ✓ 116.30 ms
# Testing 94.156.181.190:53223... ✓ 124.40 ms
# Testing 94.156.181.190:18391... ✓ 113.27 ms
# Testing 94.156.181.190:56724... ✓ 112.78 ms
# Testing 94.156.181.190:15881... ✓ 113.89 ms
# Testing 94.156.181.190:45217... ✓ 140.17 ms
# Testing 134.195.198.147:443... ✗ Failed
# Testing 134.195.198.147:443... ✓ 2356.52 ms
# Testing hgtrojan.zabc.net:2083... ✓ 3567.58 ms
# Testing 57.128.189.240:443... ✓ 128.51 ms
# Testing 91.134.8.101:443... ✓ 139.85 ms
# Testing frankfurt01.zgjok.com:443... ✓ 359.48 ms
# Testing 23.162.200.227:443... ✓ 201.99 ms
# Testing 57.129.24.125:443... ✓ 123.57 ms
# Testing lv4.789900.xyz:2087... ✗ Failed
# Testing dv4.789900.xyz:2096... ✗ Failed
# Testing 51.79.102.253:80... ✗ Failed
# Testing frankfurt02.zgjok.com:443... ✗ Failed
# Testing 15.235.41.200:80... ✓ 28.18 ms
# Testing 209.126.84.189:443... ✓ 84.04 ms
# Testing v2ray.codefyinc.com:443... ✗ Failed
# Testing turk1.net.net:80... ✗ Failed
# Testing sy4.620720.xyz:443... ✗ Failed
# Testing t1.620720.xyz:8443... ✗ Failed
# Testing 47.243.135.74:55185... ✓ 607.68 ms
# Testing singapore02.zgjok.com:443... ✗ Failed
# Testing c7.620720.xyz:8443... ✗ Failed
# Testing turk1.net.net:80... ✗ Failed
# Testing nextmi.hajmyab.ir:2053... ✓ 5045.54 ms
# Testing 47.250.45.234:43063... ✓ 326.30 ms
# Testing 47.244.120.197:44867... ✓ 500.56 ms
# Testing 47.244.120.197:36703... ✓ 457.85 ms
# Testing vjp1.0bad.com:443... ✗ Failed
# Testing vjp3.0bad.com:443... ✓ 450.36 ms
# Testing 103.253.26.134:443... ✗ Failed
# Testing 180.215.130.123:46452... ✗ Failed
# Testing 8.214.33.158:80... ✗ Failed
# Testing 202.61.141.130:443... ✗ Failed
# Testing 103.253.26.20:443... ✗ Failed
# Testing 180.215.130.123:11584... ✗ Failed
# Testing 134.195.198.147:443... ✓ 391.53 ms
# Testing hgtrojan.zabc.net:2083... ✓ 15426.24 ms
# Testing 134.195.198.147:443... ✗ Failed
# Testing 57.128.189.240:443... ✓ 187.10 ms
#
# Summary: 293 successful, 355 failed
#      Unnamed: 0                                              links  \
# 0           728  vmess://eyJhZGQiOiI1LjgzLjE1MC4xMDgiLCJob3N0Ij...
# 1           729  vmess://eyJhZGQiOiI1LjgzLjE1MC4xMDgiLCJob3N0Ij...
# 2           723  vmess://eyJhZGQiOiI1LjgzLjE1MC4xMDgiLCJob3N0Ij...
# 3           155  vmess://ew0KICAidiI6ICIyIiwNCiAgInBzIjogIlx1RD...
# 4            70  vmess://eyJhZGQiOiI4LjYuMTEyLjAiLCJhaWQiOiIwIi...
# ..          ...                                                ...
# 288         120  vmess://eyJhZGQiOiJzcGVlZHRlc3QubmV0IiwiYWlkIj...
# 289         100  vmess://eyJhZGQiOiJjYWxsbWV2cG44LmNhbGxtZXNob3...
# 290         794  vmess://ewogICAgImFkZCI6ICJoZ3Ryb2phbi56YWJjLm...
# 291          84  vmess://eyJhZGQiOiJzZXJ2ZXJzLnh2b24uaW4iLCJhaW...
# 292         445  vmess://eyJhZGQiOiJzZW91bDAzLnpnam9rLmNvbSIsIm...
#
#                                            json_config  tcp_latency_ms
# 0    {"log": {"loglevel": "warning"}, "inbounds": [...       25.811672
# 1    {"log": {"loglevel": "warning"}, "inbounds": [...       26.057720
# 2    {"log": {"loglevel": "warning"}, "inbounds": [...       26.614904
# 3    {"log": {"loglevel": "warning"}, "inbounds": [...       28.021574
# 4    {"log": {"loglevel": "warning"}, "inbounds": [...       28.148651
# ..                                                 ...             ...
# 288  {"log": {"loglevel": "warning"}, "inbounds": [...    13271.260262
# 289  {"log": {"loglevel": "warning"}, "inbounds": [...    15422.569036
# 290  {"log": {"loglevel": "warning"}, "inbounds": [...    15426.237106
# 291  {"log": {"loglevel": "warning"}, "inbounds": [...    20100.023031
# 292  {"log": {"loglevel": "warning"}, "inbounds": [...    20403.231382
#
# [293 rows x 4 columns]

# %%
import asyncio
import pandas as pd
import json
import subprocess
import socket
import time
import tempfile
import copy
from playwright.async_api import async_playwright

# ============================================================
# System-level configuration
# ============================================================

# Absolute path to system Chrome/Chromium binary
# Required because Playwright is launched manually
CHROME_PATH = "/usr/bin/google-chrome"

# ============================================================
# Target websites for full proxy functionality testing
# These represent real-world blocked or sensitive services
# ============================================================

TEST_SITES = {
    "youtube": "https://www.youtube.com",
    "telegram": "https://web.telegram.org",
    "instagram": "https://www.instagram.com",
    "chatgpt": "https://chat.openai.com",
}

# ============================================================
# Test a single VMESS/Xray config using:
# 1) Local SOCKS proxy via Xray
# 2) Real browser traffic via Playwright
# ============================================================

async def test_single_config_async(config_dict, local_port):
    """
    Launch Xray with a single config, expose SOCKS proxy,
    then verify real browsing capability using Playwright.

    Returns:
        dict containing availability and per-site latency results
    """
    result = {"proxy_alive": False}

    # Validate input
    if not isinstance(config_dict, dict):
        return result

    # Clone config to avoid mutating original object
    config = copy.deepcopy(config_dict)

    # Override SOCKS inbound port to avoid collisions
    for inbound in config.get("inbounds", []):
        if inbound.get("protocol") == "socks":
            inbound["port"] = local_port

    # Write config to a temporary JSON file
    with tempfile.NamedTemporaryFile("w", delete=False, suffix=".json") as f:
        json.dump(config, f, indent=2)
        config_path = f.name

    # Launch Xray as a subprocess
    proc = subprocess.Popen(
        ["xray", "run", "-c", config_path],
        stdout=subprocess.DEVNULL,
        stderr=subprocess.DEVNULL
    )

    # --------------------------------------------------------
    # Wait until SOCKS port becomes reachable (max 15s)
    # --------------------------------------------------------
    start = time.time()
    while time.time() - start < 15:
        try:
            with socket.create_connection(("127.0.0.1", local_port), timeout=1):
                result["proxy_alive"] = True
                break
        except Exception:
            await asyncio.sleep(0.5)

    # Abort if proxy failed to initialize
    if not result["proxy_alive"]:
        proc.terminate()
        proc.wait()
        return result

    # --------------------------------------------------------
    # Real traffic test via Playwright browser
    # --------------------------------------------------------
    async with async_playwright() as p:
        browser = await p.chromium.launch(
            executable_path=CHROME_PATH,
            proxy={"server": f"socks5://127.0.0.1:{local_port}"},
            headless=True
        )

        context = await browser.new_context()
        page = await context.new_page()

        # Visit each target site and measure navigation latency
        for name, url in TEST_SITES.items():
            try:
                t0 = time.time()
                await page.goto(url, timeout=30000)  # 30s navigation timeout
                latency_ms = (time.time() - t0) * 1000

                result[f"{name}_latency_ms"] = latency_ms
                result[f"{name}_status"] = 200

            except Exception:
                result[f"{name}_latency_ms"] = None
                result[f"{name}_status"] = None

        await browser.close()

    # Cleanly terminate Xray process
    proc.terminate()
    proc.wait()

    return result

# ============================================================
# Batch testing for entire DataFrame
# Each config gets its own SOCKS port
# ============================================================

async def test_vless_df_async(df, start_port=10808):
    """
    Run full async tests for all configs in DataFrame.

    Each config:
    - Runs Xray on a unique local port
    - Is tested concurrently using asyncio
    """
    tasks = []

    # Create async tasks with unique ports
    for i in range(len(df)):
        tasks.append(
            test_single_config_async(
                df.loc[i, "json_config"],
                start_port + i
            )
        )

    completed = 0
    final_results = []

    # Collect results as tasks finish (not sequential order)
    for coro in asyncio.as_completed(tasks):
        res = await coro
        final_results.append(res)
        completed += 1
        print(f"✅ Finished {completed}/{len(df)}")

    # Merge results back into original DataFrame
    results_df = pd.DataFrame(final_results)
    return pd.concat([df.reset_index(drop=True), results_df], axis=1)

# ============================================================
# Execution
# ============================================================

# Convert JSON strings back into Python dicts
vless_df["json_config"] = vless_df["json_config"].apply(json.loads)

# Run async test loop (Jupyter-compatible)
vless_df = await test_vless_df_async(vless_df)

# Keep only configs that successfully initialized proxy
vless_df = vless_df[vless_df["proxy_alive"]].reset_index(drop=True)

# Persist final validated configs
vless_df.to_excel(
    '/home/alireza/github/My-automated-life/Config_Automation/data/3)Config_Test_Results.xlsx'
)

vless_df
